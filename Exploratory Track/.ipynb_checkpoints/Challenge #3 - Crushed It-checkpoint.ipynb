# %% [markdown]
# # Challenge #3 Crushed It
#
# I suspect many of you have heard of the [Hydraulic Press Channel](https://www.youtube.com/c/HydraulicPressChannel). It's rather good!
#
# Build a tool that simulates crushing some common solid objects between two steel plates.
#
# Things to think about:
#
# - What sort of things might be *useful* to know about as well as entertaining?
# - We use steel plates because they're easy, but would other materials work better?
# - What about piercing rather than crushing?
#
#
# ## The Spec
#
# Simulate two steel plates and place custom objects between them. Crush the objects and find the forces required to break them!

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('ySPwjxvG6g0', width=600, height=400)
