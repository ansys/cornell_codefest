# %% [markdown]
# # Challenge #5: Tile Smasher
#
# Rather than hurting your hand punching masonry, write some simple PyMAPDL code that calculates if you have the strength to punch through a stack of roof tiles!
#
# Create an application that lets a user specify the roof tile and shape from some presets, and enter their "punching power" (however you choose to model that!), then calculate the number of tiles they break (if any), and how much force is applied to their fist in the process!
#
# Advanced Goal:
#
# * How much damage do they do to their fist in the process?

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('jluz-5UZ0vM', width=600, height=400)

# %% [markdown]
# Tips:
#
# * Consider using [ipywidgets](https://ipywidgets.readthedocs.io/en/latest/) to build a GUI if you want one, if you're happy to work in the jupyter notebook exclusively
# * Feel free to make as many assumptions as you need about the situation! If you only have time to simulate the fist as a sphere in a vacuum then that's OK! But also if you model an entire and realistic hand, you *will* get props for it. Don't be afraid to use your own judgement.
#     * These challenges are suggestions, and leaping-off points primarily.
#     * You will be rewarded for creativity and imagination!
